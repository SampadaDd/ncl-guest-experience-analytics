# %%
# !pip -q install pandas numpy scikit-learn nltk matplotlib

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, precision_recall_curve, auc
from sklearn.linear_model import LogisticRegression

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("vader_lexicon")

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df = pd.read_excel("2024 Comment Report.xlsx")
df.head()
# Out:
#         Ship Class                                           COMMENTS
# 0  Breakaway Class  Overall cruise expetience was Good. Food in th...
# 1  Breakaway Class  The ship is showing its age and should have be...
# 2  Breakaway Class   did not like  that  therwas no general seating ,
# 3  Breakaway Class  My balcony ststeroom was gross. It smelled dus...
# 4  Breakaway Class  Because I had a smell in my room. And all the ...

# %%
df.columns
# Out:
# Index(['Ship Class', 'COMMENTS'], dtype='object')

# %%
import pandas as pd

df = df.copy()

df = df.rename(columns={
    "Ship Class": "class",
    "COMMENTS": "comment_text"
})

df[["class", "comment_text"]].head()
# Out:
#              class                                       comment_text
# 0  Breakaway Class  Overall cruise expetience was Good. Food in th...
# 1  Breakaway Class  The ship is showing its age and should have be...
# 2  Breakaway Class   did not like  that  therwas no general seating ,
# 3  Breakaway Class  My balcony ststeroom was gross. It smelled dus...
# 4  Breakaway Class  Because I had a smell in my room. And all the ...

# %%
# Make sure text is string
df["comment_text"] = df["comment_text"].astype(str)

# Remove empty / whitespace-only comments
df = df[df["comment_text"].str.strip().ne("")]

# Drop duplicate comments
df = df.drop_duplicates(subset=["comment_text"])

print("Rows after cleaning:", len(df))
df.head()
# Out:
# Rows after cleaning: 411694
#              class                                       comment_text
# 0  Breakaway Class  Overall cruise expetience was Good. Food in th...
# 1  Breakaway Class  The ship is showing its age and should have be...
# 2  Breakaway Class   did not like  that  therwas no general seating ,
# 3  Breakaway Class  My balcony ststeroom was gross. It smelled dus...
# 4  Breakaway Class  Because I had a smell in my room. And all the ...

# %%
import re

def clean_text(s: str) -> str:
    s = s.lower()
    s = re.sub(r"http\S+|www\.\S+", " ", s)      # remove URLs
    s = re.sub(r"[^a-z0-9\s']", " ", s)         # keep letters/numbers/apostrophes
    s = re.sub(r"\s+", " ", s).strip()          # normalize spaces
    return s

df["clean_text"] = df["comment_text"].apply(clean_text)

df[["comment_text", "clean_text"]].head(5)
# Out:
#                                         comment_text  \
# 0  Overall cruise expetience was Good. Food in th...
# 1  The ship is showing its age and should have be...
# 2   did not like  that  therwas no general seating ,
# 3  My balcony ststeroom was gross. It smelled dus...
# 4  Because I had a smell in my room. And all the ...
#
#                                           clean_text
# 0  overall cruise expetience was good food in the...
# 1  the ship is showing its age and should have be...
# 2       did not like that therwas no general seating
# 3  my balcony ststeroom was gross it smelled dust...
# 4  because i had a smell in my room and all the t...

# %%
import nltk
nltk.download("vader_lexicon")

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

df["sentiment"] = df["clean_text"].apply(lambda x: sia.polarity_scores(x)["compound"])

df[["clean_text", "sentiment"]].head(5)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3088956145.py in <cell line: 0>()
#       5 sia = SentimentIntensityAnalyzer()
#       6
# ----> 7 df["sentiment"] = df["clean_text"].apply(lambda x: sia.polarity_scores(x)["compound"])
#       8
#       9 df[["clean_text", "sentiment"]].head(5)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipython-input-3088956145.py in <lambda>(x)
#       5 sia = SentimentIntensityAnalyzer()
#       6
# ----> 7 df["sentiment"] = df["clean_text"].apply(lambda x: sia.polarity_scores(x)["compound"])
#       8
#       9 df[["clean_text", "sentiment"]].head(5)
#
# /usr/local/lib/python3.12/dist-packages/nltk/sentiment/vader.py in polarity_scores(self, text)
#     364         """
#     365         # text, words_and_emoticons, is_cap_diff = self.preprocess(text)
# --> 366         sentitext = SentiText(
#     367             text, self.constants.PUNC_LIST, self.constants.REGEX_REMOVE_PUNCTUATION
#     368         )
#
# /usr/local/lib/python3.12/dist-packages/nltk/sentiment/vader.py in __init__(self, text, punc_list, regex_remove_punctuation)
#     272         self.PUNC_LIST = punc_list
#     273         self.REGEX_REMOVE_PUNCTUATION = regex_remove_punctuation
# --> 274         self.words_and_emoticons = self._words_and_emoticons()
#     275         # doesn't separate words from
#     276         # adjacent punctuation (keeps emoticons & contractions)
#
# /usr/local/lib/python3.12/dist-packages/nltk/sentiment/vader.py in _words_and_emoticons(self)
#     304         """
#     305         wes = self.text.split()
# --> 306         words_punc_dict = self._words_plus_punc()
#     307         wes = [we for we in wes if len(we) > 1]
#     308         for i, we in enumerate(wes):
#
# /usr/local/lib/python3.12/dist-packages/nltk/sentiment/vader.py in _words_plus_punc(self)
#     291         words_only = {w for w in words_only if len(w) > 1}
#     292         # the product gives ('cat', ',') and (',', 'cat')
# --> 293         punc_before = {"".join(p): p[1] for p in product(self.PUNC_LIST, words_only)}
#     294         punc_after = {"".join(p): p[0] for p in product(words_only, self.PUNC_LIST)}
#     295         words_punc_dict = punc_before
#
# KeyboardInterrupt:

# %%
URGENT_KEYWORDS = [
    "refund","compensation","charged","billing","cancel","unsafe","safety","danger",
    "medical","hospital","sick","food poisoning","allergy",
    "manager","supervisor","complaint","report","harassment","assault","abuse"
]

def urgent_hits(text):
    return sum(1 for w in URGENT_KEYWORDS if w in text)

df["urgent_hits"] = df["clean_text"].apply(urgent_hits)

df[["clean_text", "urgent_hits"]].head(5)
# Out:
#                                           clean_text  urgent_hits
# 0  overall cruise expetience was good food in the...            0
# 1  the ship is showing its age and should have be...            0
# 2       did not like that therwas no general seating            0
# 3  my balcony ststeroom was gross it smelled dust...            1
# 4  because i had a smell in my room and all the t...            1

# %%
INTENSIFIERS = [
    "worst","terrible","horrible","awful","disgusting",
    "unacceptable","never","ruined","hate"
]

def intensity_hits(text):
    return sum(1 for w in INTENSIFIERS if w in text)

df["intense_hits"] = df["clean_text"].apply(intensity_hits)

df[["clean_text", "intense_hits"]].head(5)
# Out:
#                                           clean_text  intense_hits
# 0  overall cruise expetience was good food in the...             0
# 1  the ship is showing its age and should have be...             2
# 2       did not like that therwas no general seating             0
# 3  my balcony ststeroom was gross it smelled dust...             1
# 4  because i had a smell in my room and all the t...             0

# %%
df["word_count"] = df["clean_text"].apply(lambda x: len(x.split()))
df["has_number"] = df["clean_text"].str.contains(r"\d").astype(int)

df[["clean_text", "word_count", "has_number"]].head(5)
# Out:
#                                           clean_text  word_count  has_number
# 0  overall cruise expetience was good food in the...          43           0
# 1  the ship is showing its age and should have be...         159           0
# 2       did not like that therwas no general seating           8           0
# 3  my balcony ststeroom was gross it smelled dust...         270           1
# 4  because i had a smell in my room and all the t...          50           0

# %%
df.columns
# Out:
# Index(['class', 'comment_text', 'clean_text', 'urgent_hits', 'intense_hits',
#        'word_count', 'has_number'],
#       dtype='object')

# %%
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

# 1) Sentiment in one pass (faster)
sent = df["clean_text"].apply(sia.polarity_scores)
sent_df = pd.DataFrame(list(sent))  # columns: neg, neu, pos, compound
sent_df = sent_df.rename(columns={
    "compound": "sent_compound",
    "neg": "sent_neg",
    "pos": "sent_pos",
    "neu": "sent_neu"
})

# %%
# 2) Other features (lightweight)
df["word_count"] = df["clean_text"].str.split().str.len()
df["exclamations"] = df["comment_text"].str.count("!")
df["has_number"] = df["comment_text"].str.contains(r"\d", regex=True).astype(int)
df["negation_hits"] = df["clean_text"].str.count(r"\b(not|never|no)\b")

# 3) Keyword hits (fast enough; small sets)
df["urgent_hits"] = df["clean_text"].apply(lambda t: sum(k in t for k in URGENT_KEYWORDS))
df["intense_hits"] = df["clean_text"].apply(lambda t: sum(k in t for k in INTENSIFIERS))

# 4) Merge sentiment back
df = pd.concat([df.reset_index(drop=True), sent_df.reset_index(drop=True)], axis=1)

df[["sent_compound","urgent_hits","intense_hits","word_count","has_number"]].head()
# Out:
#    sent_compound  urgent_hits  intense_hits  word_count  has_number
# 0         0.7709            0             0          43           0
# 1        -0.9007            0             2         159           0
# 2        -0.5122            0             0           8           0
# 3         0.9724            1             1         270           1
# 4        -0.6765            1             0          50           0

# %%
df.columns
# Out:
# Index(['class', 'comment_text', 'clean_text', 'urgent_hits', 'intense_hits',
#        'word_count', 'has_number', 'exclamations', 'negation_hits', 'sent_neg',
#        'sent_neu', 'sent_pos', 'sent_compound'],
#       dtype='object')

# %%
def compute_severity(row):
    # 1) Negative sentiment intensity (0..1) -> up to 45 points
    neg_intensity = max(0, -row["sent_compound"])     # 0 to 1
    score = 45 * neg_intensity

    # 2) Urgency / escalation cues -> up to 30 points
    score += 10 * min(row["urgent_hits"], 3)          # cap at 3 => +30

    # 3) Strong negative language -> up to 15 points
    score += 5 * min(row["intense_hits"], 3)          # cap at 3 => +15

    # 4) Specificity (more detailed complaints are often more actionable) -> up to 10 points
    score += 0.05 * min(row["word_count"], 200)       # cap words => +10

    # Bound 0..100
    return float(max(0, min(100, score)))

df["severity_score"] = df.apply(compute_severity, axis=1)
df["severity_score"].describe()
# Out:
# count    411694.000000
# mean         13.695666
# std          16.907280
# min           0.000000
# 25%           1.600000
# 50%           5.400000
# 75%          20.053500
# max          99.896500
# Name: severity_score, dtype: float64

# %%
df["severity_band"] = pd.cut(
    df["severity_score"],
    bins=[-1, 25, 50, 75, 100],
    labels=["Low", "Medium", "High", "Critical"]
)

df["severity_band"].value_counts(normalize=True).mul(100).round(2)
# Out:
# severity_band
# Low         79.25
# Medium      15.68
# High         4.62
# Critical     0.45
# Name: proportion, dtype: float64

# %%
df["escalation_risk"] = df["severity_band"].isin(["High", "Critical"]).astype(int)

df["escalation_risk"].value_counts(normalize=True).mul(100).round(2)
# Out:
# escalation_risk
# 0    94.93
# 1     5.07
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

FEATURES = [
    "sent_compound","sent_neg","sent_pos",
    "urgent_hits","intense_hits",
    "word_count","has_number","exclamations","negation_hits"
]

X = df[FEATURES]
y = df["escalation_risk"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    stratify=y,
    random_state=42
)

len(X_train), len(X_test)
# Out:
# (308770, 102924)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=2000, class_weight="balanced")
model.fit(X_train, y_train)

proba = model.predict_proba(X_test)[:,1]
pred = (proba >= 0.5).astype(int)

# %%
from sklearn.metrics import classification_report, roc_auc_score

print(classification_report(y_test, pred))
print("ROC-AUC:", roc_auc_score(y_test, proba))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     97707
#            1       0.83      1.00      0.91      5217
#
#     accuracy                           0.99    102924
#    macro avg       0.92      0.99      0.95    102924
# weighted avg       0.99      0.99      0.99    102924
#
# ROC-AUC: 0.9993476386319601

# %%
import pandas as pd

coef = pd.Series(
    model.coef_[0],
    index=FEATURES
).sort_values(ascending=False)

coef
# Out:
# urgent_hits       9.415231
# intense_hits      4.915118
# sent_neg          3.254186
# has_number        0.093551
# word_count        0.044107
# negation_hits     0.005244
# exclamations      0.000483
# sent_pos         -4.441444
# sent_compound   -38.252630
# dtype: float64

# %%
# Top 20 highest escalation-risk comments
top_risk = df.sort_values("severity_score", ascending=False).head(20)

top_risk_view = top_risk[
    ["class","severity_score","urgent_hits","intense_hits","sent_compound","word_count","comment_text"]
].copy()

# Sanitize comment display
top_risk_view["comment_text"] = top_risk_view["comment_text"].str.slice(0, 200) + "..."

top_risk_view
# Out:
#                   class  severity_score  urgent_hits  intense_hits  \
# 238921       Dawn Class         99.8965            4             3
# 63791        Dawn Class         99.8470            3             4
# 400685       Epic Class         99.8380            4             4
# 386509       Dawn Class         99.8335            5             4
# 42424   Breakaway Class         99.8200            4             6
# 204462  Breakaway Class         99.8110            3             3
# 1939        Jewel Class         99.8065            4             3
# 260749        PoA Class         99.7930            4             3
# 144213  Breakaway Class         99.7390            3             3
# 354677      Jewel Class         99.7075            4             5
# 13701         PoA Class         99.5545            3             3
# 138514  Breakaway Class         99.5545            3             3
# 367995       Epic Class         99.4960            3             3
# 184611      Prima Class         99.4870            5             3
# 242213      Jewel Class         99.4150            3             3
# 115203  Breakaway Class         99.3725            3             3
# 326650        PoA Class         99.3475            3             3
# 337239       Epic Class         99.3295            3             3
# 157681       Epic Class         99.3070            4             3
# 343719  Breakaway Class         99.2170            4             3
#
#         sent_compound  word_count  \
# 238921        -0.9977         584
# 63791         -0.9966         283
# 400685        -0.9964         714
# 386509        -0.9963         403
# 42424         -0.9960         372
# 204462        -0.9958         357
# 1939          -0.9957         589
# 260749        -0.9954         690
# 144213        -0.9942         708
# 354677        -0.9935         784
# 13701         -0.9901         845
# 138514        -0.9901         390
# 367995        -0.9888         357
# 184611        -0.9886         526
# 242213        -0.9870         316
# 115203        -0.9905         196
# 326650        -0.9855         213
# 337239        -0.9851         737
# 157681        -0.9846         447
# 343719        -0.9826         490
#
#                                              comment_text
# 238921  As mentioned in my review answers, I am VERY d...
# 63791   I have cruised for over 40 years on many diffe...
# 400685  Upon boarding, I discovered when I looked at m...
# 386509  For many people this was supposed to be a once...
# 42424   We were sick almost the entire time. We picked...
# 204462  If you look at my Prior comments regarding sho...
# 1939    where to begin..first embark process: there we...
# 260749  RESTAURANTS. (1) Service was mediocre to awful...
# 144213  Our overall experience was good, but not great...
# 354677  Upon being allowed in our room we were greeted...
# 13701   en nuestra experiencia nos fue muy mal ya que ...
# 138514  This was the worst cruise we have ever been on...
# 367995  The food was always cold, and the restaurants ...
# 184611  El crucero en general fue un infierno. Las col...
# 242213  Yes! I wish there was a rating worse then poor...
# 115203  Your cruise left late from NYC. Arrived late i...
# 326650  The ports of call is what made this cruise wor...
# 337239  There were so many things wrong. Worst cruise ...
# 157681  Experience was poisoned after first contact wi...
# 343719  We were the last cruise of the season. Staff v...

# %%
severity_summary = (
    df.groupby(["class", "severity_band"])
      .size()
      .reset_index(name="count")
)

severity_summary["pct"] = (
    severity_summary
    .groupby("class")["count"]
    .transform(lambda x: x / x.sum() * 100)
)

severity_summary.sort_values(["class","severity_band"])
# Out:
# /tmp/ipython-input-653764745.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["class", "severity_band"])
#               class severity_band   count        pct
# 0   Breakaway Class           Low  150011  80.783108
# 1   Breakaway Class        Medium   27196  14.645442
# 2   Breakaway Class          High    7741   4.168641
# 3   Breakaway Class      Critical     748   0.402809
# 4        Dawn Class           Low   16856  66.611342
# 5        Dawn Class        Medium    5720  22.604228
# 6        Dawn Class          High    2411   9.527761
# 7        Dawn Class      Critical     318   1.256669
# 8        Epic Class           Low   24280  73.533420
# 9        Epic Class        Medium    6469  19.591750
# 10       Epic Class          High    2084   6.311518
# 11       Epic Class      Critical     186   0.563312
# 12      Jewel Class           Low   57193  80.679654
# 13      Jewel Class        Medium   10682  15.068628
# 14      Jewel Class          High    2750   3.879304
# 15      Jewel Class      Critical     264   0.372413
# 16        PoA Class           Low   16194  80.439102
# 17        PoA Class        Medium    3125  15.522551
# 18        PoA Class          High     741   3.680707
# 19        PoA Class      Critical      72   0.357640
# 20      Prima Class           Low   37268  82.021260
# 21      Prima Class        Medium    6255  13.766314
# 22      Prima Class          High    1774   3.904307
# 23      Prima Class      Critical     140   0.308119
# 24     Spirit Class           Low    5201  79.138771
# 25     Spirit Class        Medium    1048  15.946439
# 26     Spirit Class          High     298   4.534388
# 27     Spirit Class      Critical      25   0.380402
# 28        Sun Class           Low   19282  78.242168
# 29        Sun Class        Medium    4047  16.421847
# 30        Sun Class          High    1222   4.958611
# 31        Sun Class      Critical      93   0.377374

# %%
df_export = df[
    ["class","severity_score","severity_band",
     "urgent_hits","intense_hits","sent_compound","word_count"]
]

df_export.to_csv("severity_scored_comments_summary.csv", index=False)
severity_summary.to_csv("severity_distribution_by_class.csv", index=False)
